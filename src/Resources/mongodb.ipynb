# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://alumarobin:voIb9l8syfsCy4K6@fever-medication-data01.nnizo.mongodb.net/?retryWrites=true&w=majority&appName=Fever-Medication-Data01"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd
from typing import List

# %%
data = pd.read_csv(r'C:\Users\Robin Aluma\Desktop\fever_medicines\medication_data\enhanced_fever_medicine_recommendation.csv')
data.head()
# Out:
#    Temperature Fever_Severity  Age  Gender   BMI Headache Body_Ache Fatigue  \
# 0         36.1         Normal   89  Female  24.0       No       Yes      No
# 1         37.5     Mild Fever   94    Male  26.6       No        No      No
# 2         36.4         Normal   92    Male  27.8       No        No      No
# 3         39.8     High Fever   66    Male  18.7       No       Yes      No
# 4         39.3     High Fever   28    Male  21.0       No       Yes      No
#
#   Chronic_Conditions Allergies Smoking_History Alcohol_Consumption  Humidity  \
# 0                 No       Yes              No                 Yes      81.4
# 1                Yes        No             Yes                 Yes      44.4
# 2                 No        No              No                 Yes      73.7
# 3                 No        No              No                  No      44.1
# 4                Yes       Yes             Yes                 Yes      65.9
#
# ...

# %%
database_data = data.to_dict('records')
print(type(database_data))
print(database_data[0])
# Out:
# <class 'list'>
# {'Temperature': 36.1, 'Fever_Severity': 'Normal', 'Age': 89, 'Gender': 'Female', 'BMI': 24.0, 'Headache': 'No', 'Body_Ache': 'Yes', 'Fatigue': 'No', 'Chronic_Conditions': 'No', 'Allergies': 'Yes', 'Smoking_History': 'No', 'Alcohol_Consumption': 'Yes', 'Humidity': 81.4, 'AQI': 430, 'Physical_Activity': 'Moderate', 'Diet_Type': 'Vegan', 'Heart_Rate': 72, 'Blood_Pressure': 'Normal', 'Previous_Medication': nan, 'Recommended_Medication': 'Ibuprofen'}

# %%
database = client["Medication_Database"]
collection = database["Medication"]
results = collection.insert_many(database_data)
results

# %%
type(results)
# Out:
# pymongo.results.InsertManyResult

# %%
data = list(collection.find())

df = pd.DataFrame(data)
df.head()
# Out:
#                         _id  Temperature Fever_Severity  Age  Gender   BMI  \
# 0  67a1275997e9a12bb9546c15         36.1         Normal   89  Female  24.0
# 1  67a1275997e9a12bb9546c16         37.5     Mild Fever   94    Male  26.6
# 2  67a1275997e9a12bb9546c17         36.4         Normal   92    Male  27.8
# 3  67a1275997e9a12bb9546c18         39.8     High Fever   66    Male  18.7
# 4  67a1275997e9a12bb9546c19         39.3     High Fever   28    Male  21.0
#
#   Headache Body_Ache Fatigue Chronic_Conditions  ... Smoking_History  \
# 0       No       Yes      No                 No  ...              No
# 1       No        No      No                Yes  ...             Yes
# 2       No        No      No                 No  ...              No
# 3       No       Yes      No                 No  ...              No
# 4       No       Yes      No                Yes  ...             Yes
#
#   Alcohol_Consumption Humidity  AQI  Physical_Activity       Diet_Type  \
# ...
